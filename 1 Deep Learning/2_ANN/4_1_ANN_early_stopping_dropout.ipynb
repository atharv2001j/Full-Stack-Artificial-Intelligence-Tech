# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('cancer_classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %% [markdown]
# # Train Test Split

# %%
X = df.drop('benign_0__mal_1',axis=1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# <h2> Scaling Data </h2>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# <h2> Creating a Model </h2>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model = Sequential()
model.add(Dense(units=30,activation='relu'))
model.add(Dense(units=15,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %% [markdown]
# # Training the model

# %%
model.fit(x=X_train,
         y=y_train,
         epochs=600,
         validation_data=(X_test,y_test),verbose=1)
# Out:
# Epoch 1/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.6998 - val_loss: 0.6886
# Epoch 2/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6848 - val_loss: 0.6771
# Epoch 3/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6715 - val_loss: 0.6557
# Epoch 4/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6529 - val_loss: 0.6209
# Epoch 5/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6067 - val_loss: 0.5703
# Epoch 6/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5681 - val_loss: 0.5095
# Epoch 7/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5264 - val_loss: 0.4554
# Epoch 8/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4701 - val_loss: 0.4069
# Epoch 9/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4302 - val_loss: 0.3616
# Epoch 10/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3886 - val_loss: 0.3179
# Epoch 11/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3563 - val_loss: 0.2832
# Epoch 12/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <Axes: >

# %%
# here we see that after a particular point the losss value remain constant so for the making the model more effective Early-stopping we use

# %% [markdown]
# # Example 2: Early Stopping

# %%
model = Sequential()
model.add(Dense(units=30,activation='relu'))
model.add(Dense(units=15,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)
# patience=Number of epochs with no improvement after which training will be done default it will be 0

# %%
model.fit(x=X_train,
         y=y_train,
         epochs=600,
         validation_data=(X_test,y_test),verbose=1,
         callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.7050 - val_loss: 0.6792
# Epoch 2/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6715 - val_loss: 0.6423
# Epoch 3/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6391 - val_loss: 0.5961
# Epoch 4/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6011 - val_loss: 0.5464
# Epoch 5/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5500 - val_loss: 0.4927
# Epoch 6/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5038 - val_loss: 0.4355
# Epoch 7/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4532 - val_loss: 0.3690
# Epoch 8/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3852 - val_loss: 0.3129
# Epoch 9/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3357 - val_loss: 0.2726
# Epoch 10/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2959 - val_loss: 0.2446
# Epoch 11/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2845 - val_loss: 0.2210
# Epoch 12/600
# ...

# %%
model_loss=pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <Axes: >

# %%
# Here we can see the model will be optimize and alsso the execytion time will bw less

# %% [markdown]
# # Example 3: Dropout

# %%
model1 = Sequential()
model1.add(Dense(units=30,activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(units=15,activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(units=1,activation='sigmoid'))
model1.compile(loss='binary_crossentropy',optimizer='adam')

# %%
model1.fit(x=X_train,
         y=y_train,
         epochs=600,
         validation_data=(X_test,y_test),verbose=1,
         callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.7103 - val_loss: 0.6808
# Epoch 2/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6941 - val_loss: 0.6740
# Epoch 3/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6876 - val_loss: 0.6636
# Epoch 4/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6698 - val_loss: 0.6493
# Epoch 5/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6626 - val_loss: 0.6299
# Epoch 6/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6378 - val_loss: 0.6089
# Epoch 7/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6321 - val_loss: 0.5793
# Epoch 8/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5925 - val_loss: 0.5433
# Epoch 9/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5615 - val_loss: 0.5103
# Epoch 10/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5615 - val_loss: 0.4832
# Epoch 11/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5727 - val_loss: 0.4557
# Epoch 12/600
# ...

# %%
model_loss=pd.DataFrame(model1.history.history)

# %%
model_loss.plot()
# Out:
# <Axes: >

# %%
# Here we can see that the model loss will be minimum as comapre to other

# %%
model1.fit(x=X_train,
         y=y_train,
         epochs=600,
         validation_data=(X_test,y_test),verbose=1)
# Out:
# Epoch 1/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3000 - val_loss: 0.1702
# Epoch 2/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2958 - val_loss: 0.1636
# Epoch 3/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3287 - val_loss: 0.1537
# Epoch 4/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2613 - val_loss: 0.1478
# Epoch 5/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2540 - val_loss: 0.1422
# Epoch 6/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2643 - val_loss: 0.1415
# Epoch 7/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2612 - val_loss: 0.1361
# Epoch 8/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2581 - val_loss: 0.1468
# Epoch 9/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2657 - val_loss: 0.1303
# Epoch 10/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2291 - val_loss: 0.1255
# Epoch 11/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2504 - val_loss: 0.1222
# Epoch 12/600
# ...

# %%
model_loss=pd.DataFrame(model1.history.history)
model_loss.plot()
# Out:
# <Axes: >

# %%
predictions=(model.predict(X_test)>0.5).astype('int32')
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95        54
#            1       0.98      0.96      0.97        89
#
#     accuracy                           0.96       143
#    macro avg       0.95      0.96      0.96       143
# weighted avg       0.96      0.96      0.96       143

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[52,  2],
#        [ 4, 85]], dtype=int64)
