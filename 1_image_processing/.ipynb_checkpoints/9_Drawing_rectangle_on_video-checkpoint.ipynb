# %% [markdown]
# # Adding the fix rectangle on the video
# we cant change the its width and height as per moment

# %%
import cv2

cap=cv2.VideoCapture(0)

#automatically grab width and height of the video feed
#(return float wich we need to convert to integer for later on)
width=int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

#we using // here because in python // allows for int classical diiviion
#because we canit pass a float to the cv2.reactangle function

#coordinartes for Rectangle, centre point rectangle
x=width//2
y=height//2

#width and height adding 1/4 of width and height from the center
w=width//4
h=height//4

while True:
    #capture frame-by-frame
    ret, frame=cap.read()
    
    #draw a recatngle on stream
    cv2.rectangle(frame,(x,y), (x+w, y+h), color=(0,0,255), thickness=4)
    
    #display the resulting framme
    cv2.imshow('frame', frame)
    
    #this command lets us quit te "q" button on a keyboard
    #simply pressing X on the button window wont work
    
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
        
#when everything is done release the capture

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Interactive Drawing on  video

# %%
-create function

# %%
import cv2
import numpy as np

# %%
#create the function based on a cv2 event (left buttonn click)
#havent drawn anything yet!

#define the global variable
pt1=(0,0)
pt2=(0,0)
topLeft_clicked=False
botRight_clicked= False

#mouse callback function this is resting the recatngle
'''
This fucntion us triggered whenever a mouse event occurs in the specified
window. It checks if the left mouse button is clicked (cv2.EVENT_LBUTTONDOWN
If both corners have already been clicked, it resets the rectangle.
If the top-left corner hasn't been clicked yet, it sets pti to the current 
mouse position and sets topleft_clicked to True. If the bottom-right corner hasn't been clicked yet,
it sets pt2 to the current mouse position and sets botRight_clicked to True.
'''

def draw_rectangle(event, x,y,flags,param):
    global pt1, pt2, topLeft_clicked, botRight_clicked
    
    #get mouse click
    if event == cv2.EVENT_LBUTTONDOWN:
    #WHEN you draw a fresh new recatngle it reset older coordinates
        if topLeft_clicked == True and botRight_clicked==True:
            topLeft_clicked = False
            botRight_clicked = False
            pt1 = (0,0)
            pt2 = (0,0)
            
        if topLeft_clicked == False:
            pt1 = (x,y)
            topLeft_clicked = True
            
        elif botRight_clicked == False:
            pt2 = (x,y)
            botRight_clicked = True
            
'''
Checking if topLeft_clicked is false:
This check is to see if the user has already clicked to set the top-left 45 corner of the rectangle.
If topleft clicked == False, it means the top-left corner has not been set yet.
Setting the first point (pti) and marking topleft_clicked as True:
pt1= (x, y) assigns the coordinates of the first click
(where the user clicks on the screen) to pt1, which represents the top-left c topLeft_clicked = True updates the flag to indicate that the top-left con

Checking if botRight_clicked is False:
This check occurs only if topleft_clicked is True (meaning the top-left corne 57 If botRight_clicked == False,
it means the bottom-right corner of the rectan Setting the second point (pt2) and 
marking botRight_clicked as True: 59 pt2 (x, y) assigns the coordinates of the second click (where the user cli
botRight_clicked = True updates the flag to indicate that the bottom.richt corner has hean cat

'''

cap=cv2.VideoCapture(0)

#create a named window for connection
cv2.namedWindow('Test')

#bind draw_rectangle function to mouse clinks

cv2.setMouseCallback('Test', draw_rectangle)


'''
Following loop continuously captures frames from the webcam.
If topLeft_clicked is True, a small red circle is drawn at pt1. 
If both topLeft_clicked and botRight_clicked are True, a red 
rectangle is drawn between pt1 and pt2. cv2.imshow('Test', frame) 
displays the video frame in the "Test" window. cv2.waitKey(1) 
& 0xFF == ord('q') checks for the 'q' key press to exit the loop 
and close the window.

'''


while True:
    ##capture frame-by-frame
    ret, frame=cap.read()
    
    #draw a recatngle on stream
    if topLeft_clicked:
        cv2.circle(frame,centre=pt1, radius=5, color=(0,0,255), thickness=-1)
    
    #drawing recatngle
    if topLeft_clicked and  botRight_clicked:
            cv2.rectangle(frame, pt1, pt2, (0,0,255), 2)
    
    #display the resulting framme
    cv2.imshow('frame', frame)
    
    #this command lets us quit te "q" button on a keyboard
    #simply pressing X on the button window wont work
    
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
        
#when everything is done release the capture

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # this is the correct code

# %%
import cv2

# Define global variables
pt1 = (0, 0)
pt2 = (0, 0)
topLeft_clicked = False
botRight_clicked = False

# Mouse callback function to draw a rectangle
def draw_rectangle(event, x, y, flags, param):
    global pt1, pt2, topLeft_clicked, botRight_clicked
    
    # Check if the left mouse button was clicked
    if event == cv2.EVENT_LBUTTONDOWN:
        
        # Reset the rectangle if both corners are already clicked
        if topLeft_clicked and botRight_clicked:
            topLeft_clicked = False
            botRight_clicked = False
            pt1 = (0, 0)
            pt2 = (0, 0)
        
        # Capture the first corner
        if not topLeft_clicked:
            pt1 = (x, y)
            topLeft_clicked = True
            
        # Capture the second corner
        elif not botRight_clicked:
            pt2 = (x, y)
            botRight_clicked = True

# Start capturing video
cap = cv2.VideoCapture(0)

# Create a named window for the video stream
cv2.namedWindow('Test')

# Bind the draw_rectangle function to mouse clicks
cv2.setMouseCallback('Test', draw_rectangle)

# Main loop to display the video stream and handle drawing
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # Draw a circle on the first corner if it's clicked
    if topLeft_clicked:
        cv2.circle(frame, center=pt1, radius=5, color=(0, 0, 255), thickness=-1)
    
    # Draw the rectangle if both corners are clicked
    if topLeft_clicked and botRight_clicked:
        cv2.rectangle(frame, pt1, pt2, (0, 0, 255), 2)
    
    # Display the resulting frame
    cv2.imshow('Test', frame)
    
    # Press 'q' to quit the loop and close the window
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
# When everything is done, release the capture and close windows
cap.release()
cv2.destroyAllWindows()
