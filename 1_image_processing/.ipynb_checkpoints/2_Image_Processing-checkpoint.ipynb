# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
img = cv2.imread("C:/Artificial Intelligence/2_Computer_Vision/1_image_processing/00-puppy.jpg")

# %% [markdown]
# ### This image is of color Blue green and red Converting to different colorspace

# %%
img= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# ## Converting to HSV

# %%
img= cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
img= cv2.imread("C:/Artificial Intelligence/2_Computer_Vision/1_image_processing/00-puppy.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
plt.imshow(img)

# %% [markdown]
# Blending and Testing image
# For some

# %%
#Blending Image
#Blendiing Image is actually quote simple Lets look at a simple example

# %%
import cv2

# %%
img1=cv2.imread("C:/Artificial Intelligence/2_Computer_Vision/1_image_processing/dog_backpack.jpg")
img2= cv2.imread("C:/Artificial Intelligence/2_Computer_Vision/1_image_processing/watermark_no_copy.png")

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img1)

# %%
img1=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
#resize the image

img1 = cv2.resize(img1, (1200, 1200))
img2= cv2.resize(img2,(1200, 1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
#Belending the image
#we will blend the value together in formula

# %%
img1.shape
# Out:
# (1200, 1200, 3)

# %%
img2.shape
# Out:
# (1200, 1200, 3)

# %%
blended =cv2.addWeighted(src1=img1, alpha=0.7, src2=img2, beta= 0.3, gamma=0)

# %%
plt.imshow(blended)

# %%
blended =cv2.addWeighted(src1=img1, alpha=0.8, src2=img2, beta= 0.2, gamma=0)
plt.imshow(blended)

# %%
blended =cv2.addWeighted(src1=img1, alpha=0.4, src2=img2, beta= 0.6, gamma=0)
plt.imshow(blended)

# %% [markdown]
# # Thresholding in image processing

# %% [markdown]
# Thresholding in image processing is a commonly used technique that involves converting an image Into a binary image by separating the pixels into two classes based on their intensity values. The process involves selecting a threshold value, which acts as a boundary between the two classes. Pixels with intensity values above the threshold are assigned one value, usually white, while those below the threshold are assigned another value, usually black, Thresholding is useful for a range of applications, including image segmentation, object detection, and image binarization. It is a single yet power tochnique that can help to simplify complex images and make than easier to analysze and process

# %%
img= cv2.imread("C:/Artificial Intelligence/2_Computer_Vision/1_image_processing/rainbow.jpg")

# %%
plt.imshow(img)

# %%
#adding tthe zero flag to read it in black and white
img= cv2.imread("C:/Artificial Intelligence/2_Computer_Vision/1_image_processing/rainbow.jpg",0)

# %%
plt.imshow(img, cmap='gray')

# %% [markdown]
# # Different Threshoding TYpe

# %% [markdown]
# # 1. Binary

# %%
ret, thresh1= cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1, cmap='gray')

# %% [markdown]
# # 2. Binary Inverse

# %%
ret, thresh2= cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)

# %%
plt.imshow(thresh2, cmap='gray')

# %% [markdown]
# # 3. Threshold Truncation

# %%
ret, thresh3= cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)

# %%
plt.imshow(thresh3, cmap='gray')

# %% [markdown]
# # 4. Threshold to Zero

# %%
ret, thresh4= cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)

# %%
plt.imshow(thresh4, cmap='gray')

# %%
# 5.

# %%
# To explore how many color space you have
print([x for x in dir(cv2) if x.startswith('COLOR_')])
# you will find list of colors space vailable
# Out:
# ['COLOR_BAYER_BG2BGR', 'COLOR_BAYER_BG2BGRA', 'COLOR_BAYER_BG2BGR_EA', 'COLOR_BAYER_BG2BGR_VNG', 'COLOR_BAYER_BG2GRAY', 'COLOR_BAYER_BG2RGB', 'COLOR_BAYER_BG2RGBA', 'COLOR_BAYER_BG2RGB_EA', 'COLOR_BAYER_BG2RGB_VNG', 'COLOR_BAYER_BGGR2BGR', 'COLOR_BAYER_BGGR2BGRA', 'COLOR_BAYER_BGGR2BGR_EA', 'COLOR_BAYER_BGGR2BGR_VNG', 'COLOR_BAYER_BGGR2GRAY', 'COLOR_BAYER_BGGR2RGB', 'COLOR_BAYER_BGGR2RGBA', 'COLOR_BAYER_BGGR2RGB_EA', 'COLOR_BAYER_BGGR2RGB_VNG', 'COLOR_BAYER_GB2BGR', 'COLOR_BAYER_GB2BGRA', 'COLOR_BAYER_GB2BGR_EA', 'COLOR_BAYER_GB2BGR_VNG', 'COLOR_BAYER_GB2GRAY', 'COLOR_BAYER_GB2RGB', 'COLOR_BAYER_GB2RGBA', 'COLOR_BAYER_GB2RGB_EA', 'COLOR_BAYER_GB2RGB_VNG', 'COLOR_BAYER_GBRG2BGR', 'COLOR_BAYER_GBRG2BGRA', 'COLOR_BAYER_GBRG2BGR_EA', 'COLOR_BAYER_GBRG2BGR_VNG', 'COLOR_BAYER_GBRG2GRAY', 'COLOR_BAYER_GBRG2RGB', 'COLOR_BAYER_GBRG2RGBA', 'COLOR_BAYER_GBRG2RGB_EA', 'COLOR_BAYER_GBRG2RGB_VNG', 'COLOR_BAYER_GR2BGR', 'COLOR_BAYER_GR2BGRA', 'COLOR_BAYER_GR2BGR_EA', 'COLOR_BAYER_GR2BGR_VNG', 'COLO
# ...
